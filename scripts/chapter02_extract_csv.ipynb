# %% [markdown]
# # 1. Extract column text and urls from excel file

# %%
import openpyxl
import re

def remove_parentheses_content(text):
    """
    移除字符串尾部括号及其内的内容
    :param text: 输入的字符串
    :return: 去掉尾部括号内容的字符串
    """
    return re.sub(r'\s*\(.*?\)$', '', text) if text else text

def read_and_process_data(excel_file_path, column_name='Name', url_column='URL', start_row=6, end_row=63):
    """
    读取 Excel 文件中指定列的文本和对应的超链接（如果存在），并按要求生成多个字段。
    
    :param excel_file_path: Excel 文件路径
    :param column_name: 包含问题名称的列名
    :param url_column: 包含 URL 的列名
    :param start_row: 开始提取数据的行号
    :return: 包含处理后数据的字典列表
    """
    workbook = openpyxl.load_workbook(excel_file_path)
    sheet = workbook.active  # 默认读取第一个工作表

    # 找到指定列的索引
    name_column_index = None
    difficulty_column_index = None
    for col in sheet.iter_cols(1, sheet.max_column):
        if not name_column_index or not difficulty_column_index:
            if col[0].value == 'Name':
                name_column_index = col[0].column
            elif col[0].value == 'Difficulty':
                difficulty_column_index = col[0].column

    if name_column_index is None or difficulty_column_index is None:
        raise ValueError(f"Column '{name_column_index}' or '{difficulty_column_index}' not found in the sheet.")

    data_list = []

    # 提取指定列的文本和超链接，从 start_row 行开始
    for index, row in enumerate(sheet.iter_rows(min_row=start_row, max_row=end_row)):

        # 1. name_cell
        name_cell = row[name_column_index - 1]

        # question_name         
        if name_cell.value:
            question_name = remove_parentheses_content(name_cell.value).strip()
        else:
            question_name = "No Name"

        # source_name
        problem_index = f"{index + 2:04d} "
        source_name = 'deep-ml-' +problem_index.replace(' ', '-') + question_name.replace(' ', '_')

        # source_name_url
        source_name_url = name_cell.hyperlink.target if name_cell.hyperlink else "No URL"

        # file_name
        file_name = (problem_index + question_name + '.ipynb').replace(' ', '_').lower()

        # file_path
        file_path = 'ipynb_codes/' + file_name

        # 2. difficulty_cell
        difficulty_cell = row[difficulty_column_index - 1]
        difficulty = difficulty_cell.value.capitalize() if difficulty_cell.value else "No Difficulty"




        print('** debug **', (question_name, source_name, source_name_url, file_name, file_path, difficulty))
        data_list.append({
            'question_name': question_name,
            'source_name': source_name,
            'source_name_url': source_name_url,
            'file_name': file_name,
            'file_path': file_path,
            'difficulty': difficulty
        })

    return data_list

# 示例使用
excel_file_path = 'deep-ml_2024.xlsx'  # 替换为实际 Excel 文件路径
data = read_and_process_data(excel_file_path)

# print('** debug **', data)
# Out:
# ** debug ** ('Transpose of a Matrix', 'deep-ml-0002-Transpose_of_a_Matrix', 'https://www.deep-ml.com/problem/Transpose%20of%20a%20Matrix', '0002_transpose_of_a_matrix.ipynb', 'ipynb_codes/0002_transpose_of_a_matrix.ipynb', 'Easy')
# ** debug ** ('Reshape Matrix', 'deep-ml-0003-Reshape_Matrix', 'https://www.deep-ml.com/problem/Reshape%20Matrix', '0003_reshape_matrix.ipynb', 'ipynb_codes/0003_reshape_matrix.ipynb', 'Easy')
# ** debug ** ('Calculate Mean by Row or Column', 'deep-ml-0004-Calculate_Mean_by_Row_or_Column', 'https://www.deep-ml.com/problem/Calculate%20Mean%20by%20Row%20or%20Column', '0004_calculate_mean_by_row_or_column.ipynb', 'ipynb_codes/0004_calculate_mean_by_row_or_column.ipynb', 'Easy')
# ** debug ** ('Scalar Multiplication of a Matrix', 'deep-ml-0005-Scalar_Multiplication_of_a_Matrix', 'https://www.deep-ml.com/problem/Scalar%20Multiplication%20of%20a%20Matrix', '0005_scalar_multiplication_of_a_matrix.ipynb', 'ipynb_codes/0005_scalar_multiplication_of_a_matrix.ipynb', 'Easy')
# ** debug ** ('Calculate Eigenvalues of a Matrix', 'deep-ml-0006-Calculate_Eigenvalues_of_a_Matrix', 'https://www.deep-ml.com/problem/Calculate%20Eigenvalues%20of%20a%20Matrix', '0006_calculate_eigenvalues_of_a_matrix.ipynb', 'ipynb_codes/0006_calculate_eigenvalues_of_a_matrix.ipynb', 'Medium')
# ** debug ** ('Matrix Transformation', 'deep-ml-0007-Matrix_Transformation', 'https://www.deep-ml.com/problem/Matrix%20Transformation', '0007_matrix_transformation.ipynb', 'ipynb_codes/0007_matrix_transformation.ipynb', 'Medium')
# ** debug ** ('Calculate 2x2 Matrix Inverse', 'deep-ml-0008-Calculate_2x2_Matrix_Inverse', 'https://www.deep-ml.com/problem/Calculate%202x2%20Matrix%20Inverse', '0008_calculate_2x2_matrix_inverse.ipynb', 'ipynb_codes/0008_calculate_2x2_matrix_inverse.ipynb', 'Medium')
# ** debug ** ('Matrix times Matrix', 'deep-ml-0009-Matrix_times_Matrix', 'https://www.deep-ml.com/problem/Matrix%20times%20Matrix', '0009_matrix_times_matrix.ipynb', 'ipynb_codes/0009_matrix_times_matrix.ipynb', 'Medium')
# ** debug ** ('Calculate Covariance Matrix', 'deep-ml-0010-Calculate_Covariance_Matrix', 'https://www.deep-ml.com/problem/Calculate%20Covariance%20Matrix', '0010_calculate_covariance_matrix.ipynb', 'ipynb_codes/0010_calculate_covariance_matrix.ipynb', 'Medium')
# ** debug ** ('Solve Linear Equations using Jacobi Method', 'deep-ml-0011-Solve_Linear_Equations_using_Jacobi_Method', 'https://www.deep-ml.com/problem/Solve%20Linear%20Equations%20using%20Jacobi%20Method', '0011_solve_linear_equations_using_jacobi_method.ipynb', 'ipynb_codes/0011_solve_linear_equations_using_jacobi_method.ipynb', 'Medium')
# ** debug ** ('Singular Value Decomposition', 'deep-ml-0012-Singular_Value_Decomposition', 'https://www.deep-ml.com/problem/Singular%20Value%20Decomposition%20(SVD)', '0012_singular_value_decomposition.ipynb', 'ipynb_codes/0012_singular_value_decomposition.ipynb', 'Medium')
# ** debug ** ("Determinant of a 4x4 Matrix using Laplace's Expansion", "deep-ml-0013-Determinant_of_a_4x4_Matrix_using_Laplace's_Expansion", "https://www.deep-ml.com/problem/Determinant%20of%20a%204x4%20Matrix%20using%20Laplace's%20Expansion", "0013_determinant_of_a_4x4_matrix_using_laplace's_expansion.ipynb", "ipynb_codes/0013_determinant_of_a_4x4_matrix_using_laplace's_expansion.ipynb", 'Hard')
# ** debug ** ('Linear Regression Using Normal Equation', 'deep-ml-0014-Linear_Regression_Using_Normal_Equation', 'https://www.deep-ml.com/problem/Linear%20Regression%20Using%20Normal%20Equation', '0014_linear_regression_using_normal_equation.ipynb', 'ipynb_codes/0014_linear_regression_using_normal_equation.ipynb', 'Easy')
# ** debug ** ('Linear Regression Using Gradient Descent', 'deep-ml-0015-Linear_Regression_Using_Gradient_Descent', 'https://www.deep-ml.com/problem/Linear%20Regression%20Using%20Gradient%20Descent', '0015_linear_regression_using_gradient_descent.ipynb', 'ipynb_codes/0015_linear_regression_using_gradient_descent.ipynb', 'Easy')
# ** debug ** ('Feature Scaling Implementation', 'deep-ml-0016-Feature_Scaling_Implementation', 'https://www.deep-ml.com/problem/Feature%20Scaling%20Implementation', '0016_feature_scaling_implementation.ipynb', 'ipynb_codes/0016_feature_scaling_implementation.ipynb', 'Easy')
# ** debug ** ('K-Means Clustering', 'deep-ml-0017-K-Means_Clustering', 'https://www.deep-ml.com/problem/K-Means%20Clustering', '0017_k-means_clustering.ipynb', 'ipynb_codes/0017_k-means_clustering.ipynb', 'Medium')
# ** debug ** ('Cross-Validation Data Split Implementation', 'deep-ml-0018-Cross-Validation_Data_Split_Implementation', 'https://www.deep-ml.com/problem/Cross-Validation%20Data%20Split%20Implementation', '0018_cross-validation_data_split_implementation.ipynb', 'ipynb_codes/0018_cross-validation_data_split_implementation.ipynb', 'Easy')
# ** debug ** ('Principal Component Analysis', 'deep-ml-0019-Principal_Component_Analysis', 'https://www.deep-ml.com/problem/Principal%20Component%20Analysis%20(PCA)%20Implementation', '0019_principal_component_analysis.ipynb', 'ipynb_codes/0019_principal_component_analysis.ipynb', 'Medium')
# ** debug ** ('Decision Tree Learning', 'deep-ml-0020-Decision_Tree_Learning', 'https://www.deep-ml.com/problem/Decision%20Tree%20Learning', '0020_decision_tree_learning.ipynb', 'ipynb_codes/0020_decision_tree_learning.ipynb', 'Hard')
# ** debug ** ('Pegasos Kernel SVM Implementation', 'deep-ml-0021-Pegasos_Kernel_SVM_Implementation', 'https://www.deep-ml.com/problem/Pegasos%20Kernel%20SVM%20Implementation', '0021_pegasos_kernel_svm_implementation.ipynb', 'ipynb_codes/0021_pegasos_kernel_svm_implementation.ipynb', 'Advanced')
# ** debug ** ('Sigmoid Activation Function Understanding', 'deep-ml-0022-Sigmoid_Activation_Function_Understanding', 'https://www.deep-ml.com/problem/Sigmoid%20Activation%20Function%20Understanding', '0022_sigmoid_activation_function_understanding.ipynb', 'ipynb_codes/0022_sigmoid_activation_function_understanding.ipynb', 'Easy')
# ** debug ** ('Softmax Activation Function Implementation', 'deep-ml-0023-Softmax_Activation_Function_Implementation', 'https://www.deep-ml.com/problem/Softmax%20Activation%20Function%20Implementation', '0023_softmax_activation_function_implementation.ipynb', 'ipynb_codes/0023_softmax_activation_function_implementation.ipynb', 'Easy')
# ** debug ** ('Single Neuron', 'deep-ml-0024-Single_Neuron', 'https://www.deep-ml.com/problem/Single%20Neuron', '0024_single_neuron.ipynb', 'ipynb_codes/0024_single_neuron.ipynb', 'Easy')
# ** debug ** ('Single Neuron with Backpropagation', 'deep-ml-0025-Single_Neuron_with_Backpropagation', 'https://www.deep-ml.com/problem/Single%20Neuron%20with%20Backpropagation', '0025_single_neuron_with_backpropagation.ipynb', 'ipynb_codes/0025_single_neuron_with_backpropagation.ipynb', 'Medium')
# ** debug ** ('Implementing Basic Autograd Operations', 'deep-ml-0026-Implementing_Basic_Autograd_Operations', 'https://www.deep-ml.com/problem/Implementing%20Basic%20Autograd%20Operations', '0026_implementing_basic_autograd_operations.ipynb', 'ipynb_codes/0026_implementing_basic_autograd_operations.ipynb', 'Medium')
# ** debug ** ('Implementing MLP Based on Autograd Operations', 'deep-ml-0027-Implementing_MLP_Based_on_Autograd_Operations', 'https://github.com/karpathy/micrograd', '0027_implementing_mlp_based_on_autograd_operations.ipynb', 'ipynb_codes/0027_implementing_mlp_based_on_autograd_operations.ipynb', 'Hard')
# ** debug ** ('Transformation Matrix from Basis B to C', 'deep-ml-0028-Transformation_Matrix_from_Basis_B_to_C', 'https://www.deep-ml.com/problem/Transformation%20Matrix%20from%20Basis%20B%20to%20C', '0028_transformation_matrix_from_basis_b_to_c.ipynb', 'ipynb_codes/0028_transformation_matrix_from_basis_b_to_c.ipynb', 'Easy')
# ** debug ** ('SVD of a 2x2 Matrix using eigen values & vectors', 'deep-ml-0029-SVD_of_a_2x2_Matrix_using_eigen_values_&_vectors', 'https://www.deep-ml.com/problem/SVD%20of%20a%202x2%20Matrix%20using%20eigen%20values%20&%20vectors', '0029_svd_of_a_2x2_matrix_using_eigen_values_&_vectors.ipynb', 'ipynb_codes/0029_svd_of_a_2x2_matrix_using_eigen_values_&_vectors.ipynb', 'Hard')
# ** debug ** ('Random Shuffle of Dataset', 'deep-ml-0030-Random_Shuffle_of_Dataset', 'https://www.deep-ml.com/problem/Random%20Shuffle%20of%20Dataset', '0030_random_shuffle_of_dataset.ipynb', 'ipynb_codes/0030_random_shuffle_of_dataset.ipynb', 'Easy')
# ** debug ** ('Batch Iterator for Dataset', 'deep-ml-0031-Batch_Iterator_for_Dataset', 'https://www.deep-ml.com/problem/Batch%20Iterator%20for%20Dataset', '0031_batch_iterator_for_dataset.ipynb', 'ipynb_codes/0031_batch_iterator_for_dataset.ipynb', 'Easy')
# ** debug ** ('Divide Dataset Based on Feature Threshold', 'deep-ml-0032-Divide_Dataset_Based_on_Feature_Threshold', 'https://www.deep-ml.com/problem/Divide%20Dataset%20Based%20on%20Feature%20Threshold', '0032_divide_dataset_based_on_feature_threshold.ipynb', 'ipynb_codes/0032_divide_dataset_based_on_feature_threshold.ipynb', 'Easy')
# ** debug ** ('Generate Polynomial Features', 'deep-ml-0033-Generate_Polynomial_Features', 'https://www.deep-ml.com/problem/Generate%20Polynomial%20Features', '0033_generate_polynomial_features.ipynb', 'ipynb_codes/0033_generate_polynomial_features.ipynb', 'Medium')
# ** debug ** ('Generate Random Subsets of a Dataset', 'deep-ml-0034-Generate_Random_Subsets_of_a_Dataset', 'https://www.deep-ml.com/problem/Generate%20Random%20Subsets%20of%20a%20Dataset', '0034_generate_random_subsets_of_a_dataset.ipynb', 'ipynb_codes/0034_generate_random_subsets_of_a_dataset.ipynb', 'Easy')
# ** debug ** ('One-Hot Encoding of Nominal Values', 'deep-ml-0035-One-Hot_Encoding_of_Nominal_Values', 'https://www.deep-ml.com/problem/One-Hot%20Encoding%20of%20Nominal%20Values', '0035_one-hot_encoding_of_nominal_values.ipynb', 'ipynb_codes/0035_one-hot_encoding_of_nominal_values.ipynb', 'Easy')
# ** debug ** ('Convert Vector to Diagonal Matrix', 'deep-ml-0036-Convert_Vector_to_Diagonal_Matrix', 'https://www.deep-ml.com/problem/Convert%20Vector%20to%20Diagonal%20Matrix', '0036_convert_vector_to_diagonal_matrix.ipynb', 'ipynb_codes/0036_convert_vector_to_diagonal_matrix.ipynb', 'Easy')
# ** debug ** ('Calculate Accuracy Score', 'deep-ml-0037-Calculate_Accuracy_Score', 'https://www.deep-ml.com/problem/Calculate%20Accuracy%20Score', '0037_calculate_accuracy_score.ipynb', 'ipynb_codes/0037_calculate_accuracy_score.ipynb', 'Easy')
# ** debug ** ('Calculate Correlation Matrix', 'deep-ml-0038-Calculate_Correlation_Matrix', 'https://www.deep-ml.com/problem/Calculate%20Correlation%20Matrix', '0038_calculate_correlation_matrix.ipynb', 'ipynb_codes/0038_calculate_correlation_matrix.ipynb', 'Medium')
# ** debug ** ('Implement AdaBoost Fit Method', 'deep-ml-0039-Implement_AdaBoost_Fit_Method', 'https://www.deep-ml.com/problem/Implement%20AdaBoost%20Fit%20Method', '0039_implement_adaboost_fit_method.ipynb', 'ipynb_codes/0039_implement_adaboost_fit_method.ipynb', 'Hard')
# ** debug ** ('Implementation of Log Softmax Function', 'deep-ml-0040-Implementation_of_Log_Softmax_Function', 'https://www.deep-ml.com/problem/Log%20Softmax', '0040_implementation_of_log_softmax_function.ipynb', 'ipynb_codes/0040_implementation_of_log_softmax_function.ipynb', 'Easy')
# ** debug ** ('Implementing a Custom Dense Layer in Python', 'deep-ml-0041-Implementing_a_Custom_Dense_Layer_in_Python', 'https://www.deep-ml.com/problem/Dense%20Layer', '0041_implementing_a_custom_dense_layer_in_python.ipynb', 'ipynb_codes/0041_implementing_a_custom_dense_layer_in_python.ipynb', 'Hard')
# ** debug ** ('Simple Convolutional 2D Layer', 'deep-ml-0042-Simple_Convolutional_2D_Layer', 'https://www.deep-ml.com/problem/Simple%20Convolutional%202D%20Layer', '0042_simple_convolutional_2d_layer.ipynb', 'ipynb_codes/0042_simple_convolutional_2d_layer.ipynb', 'Medium')
# ** debug ** ('Implement ReLU Activation Function', 'deep-ml-0043-Implement_ReLU_Activation_Function', 'https://www.deep-ml.com/problem/ReLU%20Activation%20Function', '0043_implement_relu_activation_function.ipynb', 'ipynb_codes/0043_implement_relu_activation_function.ipynb', 'Easy')
# ** debug ** ('Implement Ridge Regression Loss Function', 'deep-ml-0044-Implement_Ridge_Regression_Loss_Function', 'https://www.deep-ml.com/problem/Ridge%20Regression%20Loss', '0044_implement_ridge_regression_loss_function.ipynb', 'ipynb_codes/0044_implement_ridge_regression_loss_function.ipynb', 'Easy')
# ** debug ** ('Leaky ReLU Activation Function', 'deep-ml-0045-Leaky_ReLU_Activation_Function', 'https://www.deep-ml.com/problem/Leaky%20ReLU', '0045_leaky_relu_activation_function.ipynb', 'ipynb_codes/0045_leaky_relu_activation_function.ipynb', 'Easy')
# ** debug ** ('Linear Kernel Function', 'deep-ml-0046-Linear_Kernel_Function', 'https://www.deep-ml.com/problem/Linear%20Kernel', '0046_linear_kernel_function.ipynb', 'ipynb_codes/0046_linear_kernel_function.ipynb', 'Easy')
# ** debug ** ('Implement Precision Metric', 'deep-ml-0047-Implement_Precision_Metric', 'https://www.deep-ml.com/problem/Precision%20Metric', '0047_implement_precision_metric.ipynb', 'ipynb_codes/0047_implement_precision_metric.ipynb', 'Easy')
# ** debug ** ('Implement Gradient Descent Variants with MSE Loss', 'deep-ml-0048-Implement_Gradient_Descent_Variants_with_MSE_Loss', 'https://www.deep-ml.com/problem/Gradient%20Descent%20Variants', '0048_implement_gradient_descent_variants_with_mse_loss.ipynb', 'ipynb_codes/0048_implement_gradient_descent_variants_with_mse_loss.ipynb', 'Medium')
# ** debug ** ('Implement Reduced Row Echelon Form (RREF) Function', 'deep-ml-0049-Implement_Reduced_Row_Echelon_Form_(RREF)_Function', 'https://www.deep-ml.com/problem/Reduced%20Row%20Echelon%20Form', '0049_implement_reduced_row_echelon_form_(rref)_function.ipynb', 'ipynb_codes/0049_implement_reduced_row_echelon_form_(rref)_function.ipynb', 'Medium')
# ** debug ** ('Implement Adam Optimization Algorithm', 'deep-ml-0050-Implement_Adam_Optimization_Algorithm', 'https://www.deep-ml.com/problem/Adam%20Optimization', '0050_implement_adam_optimization_algorithm.ipynb', 'ipynb_codes/0050_implement_adam_optimization_algorithm.ipynb', 'Medium')
# ** debug ** ('Implement Lasso Regression using Gradient Descent', 'deep-ml-0051-Implement_Lasso_Regression_using_Gradient_Descent', 'https://www.deep-ml.com/problem/Lasso%20Regression%20using%20Gradient%20Descent', '0051_implement_lasso_regression_using_gradient_descent.ipynb', 'ipynb_codes/0051_implement_lasso_regression_using_gradient_descent.ipynb', 'Medium')
# ** debug ** ('Optimal String Alignment Distance', 'deep-ml-0052-Optimal_String_Alignment_Distance', 'https://www.deep-ml.com/problem/Levenshtein%20Distance', '0052_optimal_string_alignment_distance.ipynb', 'ipynb_codes/0052_optimal_string_alignment_distance.ipynb', 'Medium')
# ** debug ** ('Implement Recall Metric in Binary Classification', 'deep-ml-0053-Implement_Recall_Metric_in_Binary_Classification', 'https://www.deep-ml.com/problem/Recall', '0053_implement_recall_metric_in_binary_classification.ipynb', 'ipynb_codes/0053_implement_recall_metric_in_binary_classification.ipynb', 'Easy')
# ** debug ** ('Implement Self-Attention Mechanism', 'deep-ml-0054-Implement_Self-Attention_Mechanism', 'https://www.deep-ml.com/problem/Self-Attention%20Mechanism', '0054_implement_self-attention_mechanism.ipynb', 'ipynb_codes/0054_implement_self-attention_mechanism.ipynb', 'Medium')
# ** debug ** ('Implementing a Simple RNN', 'deep-ml-0055-Implementing_a_Simple_RNN', 'https://www.deep-ml.com/problem/RNN%20Layer', '0055_implementing_a_simple_rnn.ipynb', 'ipynb_codes/0055_implementing_a_simple_rnn.ipynb', 'Medium')
# ** debug ** ('2D Translation Matrix Implementation', 'deep-ml-0056-2D_Translation_Matrix_Implementation', 'https://www.deep-ml.com/problem/2D%20Translation%20Matrix', '0056_2d_translation_matrix_implementation.ipynb', 'ipynb_codes/0056_2d_translation_matrix_implementation.ipynb', 'Medium')
# ** debug ** ('KL Divergence Between Two Normal Distributions', 'deep-ml-0057-KL_Divergence_Between_Two_Normal_Distributions', 'https://www.deep-ml.com/problem/KL%20Divergence%20Between%20Two%20Normal%20Distributions', '0057_kl_divergence_between_two_normal_distributions.ipynb', 'ipynb_codes/0057_kl_divergence_between_two_normal_distributions.ipynb', 'Easy')
# ** debug ** ('Gauss-Seidel Method for Solving Linear Systems', 'deep-ml-0058-Gauss-Seidel_Method_for_Solving_Linear_Systems', 'https://www.deep-ml.com/problem/Gauss-Seidel%20Method', '0058_gauss-seidel_method_for_solving_linear_systems.ipynb', 'ipynb_codes/0058_gauss-seidel_method_for_solving_linear_systems.ipynb', 'Medium')
# ** debug ** ('Gaussian Elimination for Solving Linear Systems', 'deep-ml-0059-Gaussian_Elimination_for_Solving_Linear_Systems', 'https://www.deep-ml.com/problem/Gaussian%20Elimination', '0059_gaussian_elimination_for_solving_linear_systems.ipynb', 'ipynb_codes/0059_gaussian_elimination_for_solving_linear_systems.ipynb', 'Medium')

# %% [markdown]
# # 2. Generate chapter02_xlsx_to_md.md

# %%
import os

def generate_md_file(data, output_file="chapter02_xlsx_to_md.md"):
    """
    根据 data 生成一个 Markdown 文件，并将每条数据按指定格式写入表格。
    
    :param data: 包含所有问题的列表
    :param output_file: 输出的 Markdown 文件名
    """
    with open(output_file, "w") as md_file:
        # # 写入表头
        # md_file.write("<table>\n")
        # md_file.write("  <thead>\n")
        # md_file.write("    <tr>\n")
        # md_file.write("      <th rowspan=\"3\">Status</th>\n")
        # md_file.write("      <th rowspan=\"3\">Question Name</th>\n")
        # md_file.write("      <th rowspan=\"3\">Source</th>\n")
        # md_file.write("      <th rowspan=\"3\">Ipynb Implementation</th>\n")
        # md_file.write("      <th rowspan=\"3\">Difficulty</th>\n")
        # md_file.write("      <th colspan=\"4\">Complexity</th>\n")
        # md_file.write("    </tr>\n")
        # md_file.write("    <tr>\n")
        # md_file.write("      <th colspan=\"2\">Training</th>\n")
        # md_file.write("      <th colspan=\"2\">Inference</th>\n")
        # md_file.write("    </tr>\n")
        # md_file.write("    <tr>\n")
        # md_file.write("      <th>Time</th>\n")
        # md_file.write("      <th>Space</th>\n")
        # md_file.write("      <th>Time</th>\n")
        # md_file.write("      <th>Space</th>\n")
        # md_file.write("    </tr>\n")
        # md_file.write("  </thead>\n")
        # md_file.write("  <tbody>\n")
        
        # 写入每一行数据
        for item in data:
            question_name = item['question_name']
            source_name = item['source_name']
            source_name_url = item['source_name_url']
            file_name = item['file_name']
            file_path = item['file_path']
            difficulty = item['difficulty']
            
            # 根据难度设置颜色
            if difficulty.lower() == "easy":
                difficulty_color = "#28a745"  # 绿色
            elif difficulty.lower() == "medium":
                difficulty_color = "#ffc107"  # 黄色
            elif difficulty.lower() == "hard":
                difficulty_color = "#dc3545"  # 红色
            else:
                difficulty_color = "#6c757d"  # 默认灰色

            # 写入行内容
            md_file.write("    <tr>\n")
            md_file.write("      <td>☐</td>\n")
            md_file.write(f"      <td>{question_name}</td>\n")
            md_file.write(f"      <td><a href=\"{source_name_url}\">{source_name}</a></td>\n")
            md_file.write(f"      <td><a href=\"{file_path}\">{file_name}</a></td>\n")
            md_file.write(f"      <td><span style=\"color:{difficulty_color}\">{difficulty}</span></td>\n")
            md_file.write("      <td>O()</td>\n")
            md_file.write("      <td>O()</td>\n")
            md_file.write("      <td>O()</td>\n")
            md_file.write("      <td>O()</td>\n")
            md_file.write("    </tr>\n")
        
        # # 关闭表格
        # md_file.write("  </tbody>\n")
        # md_file.write("</table>\n")

# 示例使用
generate_md_file(data)
print("Markdown file has been generated: chapter02_xlsx_to_md.md")
# Out:
# Markdown file has been generated: chapter02_xlsx_to_md.md

# %%
 def generate_bash_script(data, bash_output_file="chapter02_copy_template_files.sh"):
    """
    根据 data 生成一个 Bash 文件，并将每条数据的 file_path 写入以复制模板文件。
    
    :param data: 包含所有问题的列表，每项包含 file_path 信息
    :param bash_output_file: 输出的 Bash 文件名
    """
    with open(bash_output_file, "w") as bash_file:
        # 编写 Bash 头部和模板文件路径
        bash_file.write("#!/bin/bash\n\n")
        bash_file.write("# Define the template file path\n")
        bash_file.write("TEMPLATE_FILE=\"../src/Chapter02/ipynb_codes/0000_tmplate.ipynb\"\n\n")
        
        # 写入复制命令
        bash_file.write("echo \"Starting to copy template files...\"\n\n")
        for item in data:
            # 生成目标文件的相对路径
            # print('** debug **', item['file_path'])
            relative_path = f"../src/Chapter02/{item['file_path']}"
            bash_file.write(f"mkdir -p \"$(dirname \"{relative_path}\")\"\n")
            bash_file.write(f"cp \"$TEMPLATE_FILE\" \"{relative_path}\"\n")
            bash_file.write(f"echo \"Copied to {relative_path}\"\n")
        
        bash_file.write("\necho \"All files have been copied.\"\n")


generate_bash_script(data)
print("Bash script file has been generated: chapter02_copy_template_files.sh")
# Out:
# Bash script file has been generated: chapter02_copy_template_files.sh
